# %% [markdown]
# ## **PLOT FOR RESULTS**
#
# ***

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ### **CONFUSION MATRICES**

# %% [markdown]
# from results_set_1.txt

# %%
#data
TN = 286415 #True Negative
FP = 2 #False Positive
FN = 3 #False Negative
TP = 182 #True Positive

cm = np.array([[TN,FP],
[FN,TP]])

labels = ["Negative", "Positive"]
#plot
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='BuGn',
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Real')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# %% [markdown]
# from resutls_set_2.txt

# %%
#data
TN = 286415  #True Negative
FP = 1 #False Positive
FN = 1 #Falese Negative
TP = 181 #True Positive

cm = np.array([[TN,FP],
[FN,TP]])

labels = ["Negative", "Positive"]
#plot
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges',
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Real')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Q-score vs RDMS**

# %%
# Create the data as a list of dictionaries
data = [
    {"PDB ID": "5nx1:C", "Nres": 54, "Nsse": 4, "RMSD": 0.4107, "Q-score": 0.5090},
    {"PDB ID": "6bx8:B", "Nres": 55, "Nsse": 4, "RMSD": 0.4000, "Q-score": 0.5002},
    {"PDB ID": "4bqd:A", "Nres": 78, "Nsse": 6, "RMSD": 0.3730, "Q-score": 0.3535},
    {"PDB ID": "1yc0:I", "Nres": 66, "Nsse": 4, "RMSD": 0.3357, "Q-score": 0.4190},
    {"PDB ID": "4dtg:K", "Nres": 60, "Nsse": 4, "RMSD": 0.4430, "Q-score": 0.4567},
    {"PDB ID": "1f5r:I", "Nres": 57, "Nsse": 4, "RMSD": 0.6203, "Q-score": 0.4711},
    {"PDB ID": "1zr0:B", "Nres": 63, "Nsse": 4, "RMSD": 0.4310, "Q-score": 0.4355},
    {"PDB ID": "3wny:A", "Nres": 56, "Nsse": 4, "RMSD": 0.6027, "Q-score": 0.4806},
    {"PDB ID": "1bun:B", "Nres": 61, "Nsse": 3, "RMSD": 0.7111, "Q-score": 0.4346},
    {"PDB ID": "3m7q:B", "Nres": 61, "Nsse": 4, "RMSD": 0.5230, "Q-score": 0.4455},
    {"PDB ID": "6q61:A", "Nres": 59, "Nsse": 4, "RMSD": 0.4646, "Q-score": 0.4635},
    {"PDB ID": "4ntw:B", "Nres": 60, "Nsse": 4, "RMSD": 0.7731, "Q-score": 0.4376},
    {"PDB ID": "5yv7:A", "Nres": 60, "Nsse": 4, "RMSD": 0.5173, "Q-score": 0.4532},
    {"PDB ID": "1dtx:A", "Nres": 59, "Nsse": 4, "RMSD": 0.5102, "Q-score": 0.4612},
    {"PDB ID": "3byb:A", "Nres": 58, "Nsse": 4, "RMSD": 0.4520, "Q-score": 0.4720},
    {"PDB ID": "4u30:X", "Nres": 54, "Nsse": 3, "RMSD": 0.5816, "Q-score": 0.4997},
    {"PDB ID": "6yhy:A", "Nres": 59, "Nsse": 4, "RMSD": 0.4311, "Q-score": 0.4650},
    {"PDB ID": "1knt:A", "Nres": 55, "Nsse": 4, "RMSD": 0.5897, "Q-score": 0.4902},
    {"PDB ID": "5jb7:A", "Nres": 56, "Nsse": 4, "RMSD": 0.5488, "Q-score": 0.4838},
    {"PDB ID": "5m4v:A", "Nres": 57, "Nsse": 4, "RMSD": 0.4397, "Q-score": 0.4809},
    {"PDB ID": "1yld:B", "Nres": 56, "Nsse": 4, "RMSD": 0.5875, "Q-score": 0.4815},
    {"PDB ID": "1fak:I", "Nres": 55, "Nsse": 4, "RMSD": 0.4866, "Q-score": 0.4960},
    {"PDB ID": "4u32:X", "Nres": 54, "Nsse": 3, "RMSD": 0.3114, "Q-score": 0.5130},
    {"PDB ID": "5jbt:Y", "Nres": 38, "Nsse": 4, "RMSD": 2.9166, "Q-score": 0.3788},
]

# Create DataFrame
df = pd.DataFrame(data)

# Plot Q-score vs RMSD
plt.figure(figsize=(8, 6))
plt.scatter(df["RMSD"], df["Q-score"], color='violet' \
'' \
'', s=60)
plt.xlabel("RMSD (Å)")
plt.ylabel("Q-score")
plt.title("Q-score vs RMSD of Structural Alignments")
plt.xticks(np.linspace(df["RMSD"].min(), df["RMSD"].max(), 12))    # 12 ticks on x-axis
plt.yticks(np.linspace(df["Q-score"].min(), df["Q-score"].max(), 12))  # 12 ticks on y-axis

plt.grid(True, which = "both", linestyle = "--",linewidth = 0.5, color="gray")

for i, row in df.iterrows():
    if row["RMSD"] > 1.5 or row["Q-score"] > 0.5:
        plt.text(row["RMSD"] + 0.02, row["Q-score"], row["PDB ID"], fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **MCC vs e value**

# %%
#E-value
thresholds = [
    0.1, 0.01, 0.001, 0.0001, 1e-5, 1e-6, 
    1e-7, 1e-8, 1e-9, 1e-10
    ]
thresholds2 = [
    0.1, 0.01, 0.001, 0.0001, 1e-5,
    1e-6, 1e-7, 1e-8, 1e-9, 1e-10
]

# MCC 
mmcc = [
    0.9099, 0.9662, 0.9788, 0.9891, 0.9918,
      0.9945, 0.9918, 0.9918, 
      0.9918, 0.989
      ]

mcc_values2 = [
    0.9162,
    0.9614,
    0.9891,
    0.9891,
    0.9863,
    0.9863,
    0.9835,
    0.9835,
    0.9835,
    0.9835
]


plt.figure(figsize=(8, 6))
plt.plot(thresholds, mmcc, marker='o', linestyle='-', color='green',label = "Set1")
plt.plot(thresholds2, mcc_values2, marker='o', linestyle='-', color='orange', label = "Set2")

# Slog scale x axes
plt.xscale('log')


# title, labels
plt.xlabel("E-value Threshold (log scale)")
plt.ylabel("Matthews Correlation Coefficient (MCC)")
plt.title("MCC vs E-value Threshold")
plt.legend()
# Grid
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Graph
plt.tight_layout()
plt.show()

# %%
# E-values

thresholds = [
    0.1, 0.01, 0.001, 0.0001, 1e-05, 1e-06, 1e-07, 1e-08, 1e-09, 1e-10,
    1e-11, 1e-12, 1e-13, 1e-14, 1e-15, 1e-16, 1e-17, 1e-18, 1e-19, 1e-20,
    1e-21, 1e-22, 1e-23, 1e-24, 1e-25, 1e-26, 1e-27, 1e-28, 1e-29, 1e-30
]

thresholds2 = [
    0.1, 0.01, 0.001, 0.0001, 1e-05, 1e-06, 1e-07, 1e-08, 1e-09, 1e-10,
    1e-11, 1e-12, 1e-13, 1e-14, 1e-15, 1e-16, 1e-17, 1e-18, 1e-19, 1e-20,
    1e-21, 1e-22, 1e-23, 1e-24, 1e-25, 1e-26, 1e-27, 1e-28, 1e-29, 1e-30
]


# MCC values
mcc_values2 = mcc_values = [
    0.9162,
    0.9614,
    0.9891,
    0.9891,
    0.9863,
    0.9863,
    0.9835,
    0.9835,
    0.9835,
    0.9835,
    0.9751,
    0.9751,
    0.9695,
    0.9695,
    0.961,
    0.9582,
    0.9496,
    0.9204,
    0.9084,
    0.8963,
    0.8684,
    0.8199,
    0.8029,
    0.7317,
    0.6693,
    0.5329,
    0.4115,
    0.3387,
    0.3221,
    0.3135
]


mcc_values = [
    0.9099, 0.9662, 0.9788, 0.9891, 0.9918, 0.9945, 0.9918, 0.9918, 0.9918, 0.989,
    0.9863, 0.9863, 0.9835, 0.9723, 0.9695, 0.9638, 0.9379, 0.8993, 0.8715, 0.8428,
    0.8231, 0.7926, 0.761, 0.6933, 0.6358, 0.512, 0.4181, 0.3135, 0.3135, 0.3135
]



plt.figure(figsize=(8, 6))
plt.plot(thresholds, mcc_values, marker='o', linestyle='-', color='green', label = "Set1")
plt.plot(thresholds2, mcc_values2, marker='o', linestyle='-', color='orange', label = "Set2")

# log scale for x axes
plt.xscale('log')


# label,title
plt.xlabel("E-value Threshold (log scale)")
plt.ylabel("Matthews Correlation Coefficient (MCC)")
plt.title("MCC vs E-value Threshold")
plt.legend()
# Grid
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# show graphs
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 59
#      17 mcc_values2 = mcc_values = [
#      18     0.9162,
#      19     0.9614,
#    (...)
#      47     0.3135
#      48 ]
#      51 mcc_values = [
#      52     0.9099, 0.9662, 0.9788, 0.9891, 0.9918, 0.9945, 0.9918, 0.9918, 0.9918, 0.989,
#      53     0.9863, 0.9863, 0.9835, 0.9723, 0.9695, 0.9638, 0.9379, 0.8993, 0.8715, 0.8428,
#      54     0.8231, 0.7926, 0.761, 0.6933, 0.6358, 0.512, 0.4181, 0.3135, 0.3135, 0.3135
#      55 ]
# ---> 59 plt.figure(figsize=(8, 6))
#      60 plt.plot(thresholds, mcc_values, marker='o', linestyle='-', color='green', label = "Set1")
#      61 plt.plot(thresholds2, mcc_values2, marker='o', linestyle='-', color='orange', label = "Set2")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# HMM visualisation

# %%
pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: C:\Users\utente\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### **HMM probabilities**

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Load the PNG file
img = Image.open("hmm_transition_diagram.png")

# Display the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# ## **EXAMPLE HMM**

# %%
from graphviz import Digraph

# Create graphs
dot = Digraph(format='png')
dot.attr(rankdir='LR', size='8,5')
dot.node("Start", shape="circle", style="filled", fillcolor="lightgray")
dot.node("End", shape="circle", style="filled", fillcolor="lightgray")

# example states for three columns
states_M = ['M1', 'M2', 'M3']
states_I = ['D1', 'D2', 'D3']
states_D = ['I1', 'I2', 'I3']

# nodes
for i in range(0, 3):
    dot.node(states_M[i], shape='circle', style="filled", fillcolor="lightblue")
    dot.node(states_I[i], shape="circle", style="filled", fillcolor="lightgreen")
    dot.node(states_D[i], shape="circle", style="filled", fillcolor="orange")

# Start transitions
dot.edge('Start', 'M1', label="Start")
dot.edge('Start', 'I1', label="Start")
dot.edge('Start', 'D1', label="Start")

#M1
dot.edge('M1', 'M2', label='m1->m2')
dot.edge('M1', 'I1', label='m1->i1')
dot.edge("M1", "D2", label="M1 → D2")
#I1
dot.edge('I1', 'I1', label='i1->i1')
dot.edge('I1', 'D2', label='i1->d1')
dot.edge('I1', 'M2', label='i1->m2')
#D1
dot.edge('D1', 'D2', label='d1->d2')
dot.edge('D1', 'I1', label='d1->i1')
dot.edge('D1', 'M2', label='d1->i1')


#M2
dot.edge('M2', 'M3', label='m2->m3')
dot.edge('M2', 'I2', label='m2->i2')
dot.edge('M2', 'D3', label='m2->d3')
#I2
dot.edge("I2", "D3", label="i2->d3")
dot.edge("I2", "M3", label="i2 → i3")
dot.edge("I2", "I2", label="i2 → i2")
#D2
dot.edge("D2", "D3", label="d2 → d3")
dot.edge("D2", "M3", label="m2 → m3")
dot.edge('D2', 'I2', label='d2->i2')

#M3
dot.edge("M3", "I3", label="m3 → i3")
dot.edge("M3","end", label="m3  End")
#D3
dot.edge("D3", "End", label="D3 → End")
#I3
dot.edge("I3", "I3", label="i3 → i3")
dot.edge("I3", "End", label="i3 → End")


#save and visualise
dot.render('mini_hmm')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# ...
